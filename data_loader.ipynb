# %% [markdown]
# <a href="https://colab.research.google.com/github/a-emreusta/success-of-ai-writers/blob/main/data_loader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
df_train = pd.read_csv("/content/drive/MyDrive/Success of AI Writers/DATA/snli_1.0_train.csv")

# %%
df_train.head()
# Out:
#       similarity                                          sentence1  \
# 0        neutral  A person on a horse jumps over a broken down a...
# 1  contradiction  A person on a horse jumps over a broken down a...
# 2     entailment  A person on a horse jumps over a broken down a...
# 3        neutral              Children smiling and waving at camera
# 4     entailment              Children smiling and waving at camera
#
#                                            sentence2
# 0  A person is training his horse for a competition.
# 1      A person is at a diner, ordering an omelette.
# 2                  A person is outdoors, on a horse.
# 3                  They are smiling at their parents
# 4                         There are children present

# %%
print(f"Number of unique naming's in similarity column : {df_train.similarity.nunique()}")
print(f"Number of unique naming's in similarity column : {df_train.sentence1.nunique()}")
print(f"Number of unique naming's in similarity column : {df_train.sentence2.nunique()}")
# Out:
# Number of unique naming's in similarity column : 4
# Number of unique naming's in similarity column : 150773
# Number of unique naming's in similarity column : 480122

# %%
print(f"Number of unique naming's in similarity column :")
df_train.similarity.value_counts()
# Out:
# Number of unique naming's in similarity column :
# entailment       183416
# contradiction    183187
# neutral          182764
# -                   785
# Name: similarity, dtype: int64

# %%
df_train.describe()
df_train.info()
# Out:
#         similarity          sentence1           sentence2
# count       550152             550152              550146
# unique           4             150773              480122
# top     entailment  A dog in a field.  A man is sleeping.
# freq        183416                 33                 335
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550152 entries, 0 to 550151
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   similarity  550152 non-null  object
#  1   sentence1   550152 non-null  object
#  2   sentence2   550146 non-null  object
# dtypes: object(3)
# memory usage: 12.6+ MB

# %%
df_test = pd.read_csv("/content/drive/MyDrive/Success of AI Writers/DATA/snli_1.0_test.csv")

# %%
df_test.head()
# Out:
#       similarity                                          sentence1  \
# 0        neutral  This church choir sings to the masses as they ...
# 1     entailment  This church choir sings to the masses as they ...
# 2  contradiction  This church choir sings to the masses as they ...
# 3        neutral  A woman with a green headscarf, blue shirt and...
# 4     entailment  A woman with a green headscarf, blue shirt and...
#
#                                sentence2
# 0  The church has cracks in the ceiling.
# 1        The church is filled with song.
# 2    A choir singing at a baseball game.
# 3                    The woman is young.
# 4               The woman is very happy.

# %%
df_test.describe()
# Out:
#         similarity                                          sentence1  \
# count        10000                                              10000
# unique           4                                               3323
# top     entailment  A man wearing a jacket is listening to headpho...
# freq          3368                                                  6
#
#                                  sentence2
# count                                10000
# unique                                9810
# top     There are multiple people present.
# freq                                     7
